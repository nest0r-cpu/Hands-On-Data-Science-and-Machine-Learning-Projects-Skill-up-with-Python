# %%
print("hello")
# Out:
# hello

# %%
for i in range (10): 
    print(f'hello {i}')
# Out:
# hello 0
# hello 1
# hello 2
# hello 3
# hello 4
# hello 5
# hello 6
# hello 7
# hello 8
# hello 9

# %%
import matplotlib.pyplot as plt

plt.plot([1, 2, 3, 4], [2, 10, 5, 3])
plt.ylabel('Profit')  # Changed 'plot' to 'plt' to use the correct module

plt.show()
